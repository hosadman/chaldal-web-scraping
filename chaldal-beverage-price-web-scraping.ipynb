# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
baseurl = 'https://chaldal.com/soft-drinks'

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:82.0) Gecko/20100101 Firefox/82.0'}

# %%
r = requests.get(baseurl)
soup = bs(r.content, 'lxml')

# %%
products = soup.find_all('div', class_='product')

# %%
product = []
price = []

for item in products:
    for i in item.find_all('div', class_='imageWrapper'):
        for j in i.find_all('div', class_='name'):
            product.append(j.text)
# Out:
# ['Pepsi Diet Pet', 'Coca-Cola', 'Coca-Cola', 'Coke Light Can', 'Coca-Cola Can', 'Coca-Cola', 'Sprite', 'Mountain Dew', 'Sprite', '7 Up Pet', 'Mountain Dew', 'Pepsi Pet', 'Sprite', 'Pepsi', 'Pepsi Pet', '7 Up Pet', 'Fanta', 'Pepsi Diet Can', 'Sprite Can', 'Fresh Club 9 Soda', 'Fanta', 'Amul Lassi', 'Fresh Mejanda', '7 Up Can', 'Mirinda Orange', 'Amul Pinacolada Mocktail Can', 'Mirinda Orange', 'Mountain Dew Can', 'Sprite Zero Sugar', 'Fanta Can', 'Frutika Mango Juice', 'Mirinda Can', 'Pepsi Can', 'Fresh Dhoom Cola', 'Sharbat-E-Ala', 'Sharbat-E-Ala', '7 Up Can', 'Fanta Strawberry Can', 'Pran Up', 'Pran Up', 'Fresh Soul Up', 'Wings Lemon', 'Wings Lemon', 'Clemon Can', 'Dolphin Nata De Coco Lychee Drink', 'Basil Seed Drink (Mixed Fruit)', 'Basil Seed Drink (Lemon)', 'Basil Seed Drink (Pineapple)', 'Basil Seed Drink (Lychee)', 'Basil Seed Drink (Mango)']

# %%
for item in products:
    for i in item.find_all('div', class_='imageWrapper'):
        for j in i.find_all('div', class_='price'):
            price.append(j.text)

# %%
productlist = {'product':product, 'price':price}

# %%
pd.DataFrame(productlist)
# Out:
#                               product  price
# 0                      Pepsi Diet Pet   ৳ 35
# 1                           Coca-Cola   ৳ 40
# 2                           Coca-Cola   ৳ 70
# 3                      Coke Light Can   ৳ 40
# 4                       Coca-Cola Can   ৳ 40
# 5                           Coca-Cola  ৳ 110
# 6                              Sprite   ৳ 35
# 7                        Mountain Dew   ৳ 30
# 8                              Sprite   ৳ 65
# 9                            7 Up Pet   ৳ 50
# 10                       Mountain Dew   ৳ 50
# 11                          Pepsi Pet  ৳ 100
# 12                             Sprite  ৳ 110
# 13                              Pepsi   ৳ 30
# 14                          Pepsi Pet   ৳ 50
# 15                           7 Up Pet   ৳ 35
# 16                              Fanta   ৳ 65
# 17                     Pepsi Diet Can   ৳ 40
# 18                         Sprite Can   ৳ 40
# 19                  Fresh Club 9 Soda   ৳ 30
# 20                              Fanta   ৳ 35
# 21                         Amul Lassi  ৳ 100
# 22                      Fresh Mejanda   ৳ 15
# 23                           7 Up Can   ৳ 40
# 24                     Mirinda Orange   ৳ 35
# 25       Amul Pinacolada Mocktail Can  ৳ 125
# 26                     Mirinda Orange   ৳ 50
# 27                   Mountain Dew Can   ৳ 40
# 28                  Sprite Zero Sugar   ৳ 20
# 29                          Fanta Can   ৳ 40
# 30                Frutika Mango Juice   ৳ 80
# 31                        Mirinda Can   ৳ 40
# 32                          Pepsi Can   ৳ 40
# 33                   Fresh Dhoom Cola   ৳ 50
# 34                      Sharbat-E-Ala  ৳ 300
# 35                      Sharbat-E-Ala  ৳ 170
# 36                           7 Up Can  ৳ 150
# 37               Fanta Strawberry Can  ৳ 140
# 38                            Pran Up   ৳ 25
# 39                            Pran Up   ৳ 50
# 40                      Fresh Soul Up   ৳ 15
# 41                        Wings Lemon   ৳ 50
# 42                        Wings Lemon   ৳ 25
# 43                         Clemon Can   ৳ 25
# 44  Dolphin Nata De Coco Lychee Drink  ৳ 125
# 45     Basil Seed Drink (Mixed Fruit)  ৳ 105
# 46           Basil Seed Drink (Lemon)  ৳ 105
# 47       Basil Seed Drink (Pineapple)  ৳ 110
# 48          Basil Seed Drink (Lychee)  ৳ 105
# 49           Basil Seed Drink (Mango)  ৳ 105
